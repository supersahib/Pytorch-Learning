# %% [markdown]
# <a href="https://colab.research.google.com/github/supersahib/Pytorch-Learning/blob/main/01_Pytorch_Workflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screenshot 2024-03-19 at 5.15.35 PM.png](data:image/png;base64,...)
